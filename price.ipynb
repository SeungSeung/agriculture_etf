# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas_datareader.naver as web_naver

# %%
df_tiger=web_naver.NaverDailyReader(symbols='137610', start='20110111',adjust_price=True)
df_kodex=web_naver.NaverDailyReader(symbols='271060', start='20170613',adjust_price=True)

# %%
df_tiger=df_tiger.read()
df_tiger.head()
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2011-01-11  10400  10500  10030  10065  221076
# 2011-01-12  10200  10200  10000  10005  120538
# 2011-01-13  10070  10220  10070  10200   75912
# 2011-01-14  10185  10240  10175  10200  102051
# 2011-01-17  10485  11000  10205  10450  182345

# %%
df_kodex=df_kodex.read()
df_kodex.head(10)
# Out:
#              Open   High    Low  Close Volume
# Date
# 2017-06-13   9965  10060   9965  10060  10010
# 2017-06-14  10110  10150  10110  10135   1106
# 2017-06-15  10060  10065  10025  10065    432
# 2017-06-16  10190  10210  10175  10200   6212
# 2017-06-19  10185  10275  10185  10250   4031
# 2017-06-20  10230  10285  10230  10230   2927
# 2017-06-21  10175  10185  10160  10170  20222
# 2017-06-22  10065  10065  10015  10050  11717
# 2017-06-23   9960   9960   9910   9940   4689
# 2017-06-26   9860   9920   9860   9895    738

# %%
df_tiger['Close_1']=df_tiger['Close'].shift(1)
df_tiger['Change']=np.log(df_tiger['Close'].astype(float)/df_tiger['Close_1'].astype(float))
df_tiger['label']=np.where(np.sign(df_tiger['Change'])>0,1,-1)
df_tiger
# Out:
#              Open   High    Low  Close  Volume Close_1    Change  label
# Date
# 2011-01-11  10400  10500  10030  10065  221076     NaN       NaN     -1
# 2011-01-12  10200  10200  10000  10005  120538   10065 -0.005979     -1
# 2011-01-13  10070  10220  10070  10200   75912   10005  0.019303      1
# 2011-01-14  10185  10240  10175  10200  102051   10200  0.000000     -1
# 2011-01-17  10485  11000  10205  10450  182345   10200  0.024214      1
# ...           ...    ...    ...    ...     ...     ...       ...    ...
# 2022-02-14   7275   7390   7275   7375   56284    7220  0.021241      1
# 2022-02-15   7340   7340   7295   7295   58618    7375 -0.010907     -1
# 2022-02-16   7245   7245   7150   7225   43700    7295 -0.009642     -1
# 2022-02-17   7230   7305   7225   7295   17621    7225  0.009642      1
# 2022-02-18   7390   7390   7290   7310   14117    7295  0.002054      1
#
# [2737 rows x 8 columns]

# %%
df_kodex['Close_1']=df_kodex['Close'].shift(1)
df_kodex['Change']=np.log(df_kodex['Close'].astype(float)/df_kodex['Close_1'].astype(float))
df_kodex['label']=np.where(np.sign(df_kodex['Change'])>0,1,-1)
df_kodex.head(10)
# Out:
#              Open   High    Low  Close Volume Close_1    Change  label
# Date
# 2017-06-13   9965  10060   9965  10060  10010     NaN       NaN     -1
# 2017-06-14  10110  10150  10110  10135   1106   10060  0.007428      1
# 2017-06-15  10060  10065  10025  10065    432   10135 -0.006931     -1
# 2017-06-16  10190  10210  10175  10200   6212   10065  0.013324      1
# 2017-06-19  10185  10275  10185  10250   4031   10200  0.004890      1
# 2017-06-20  10230  10285  10230  10230   2927   10250 -0.001953     -1
# 2017-06-21  10175  10185  10160  10170  20222   10230 -0.005882     -1
# 2017-06-22  10065  10065  10015  10050  11717   10170 -0.011870     -1
# 2017-06-23   9960   9960   9910   9940   4689   10050 -0.011006     -1
# 2017-06-26   9860   9920   9860   9895    738    9940 -0.004537     -1

# %%
df_kodex.to_csv('df_kodex.csv')
df_tiger.to_csv('df_tiger.csv')
